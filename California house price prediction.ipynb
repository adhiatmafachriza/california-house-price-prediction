# %% [markdown]
# # California House Price Prediction
#
# * Goal : memprediksi nilai median jual harga rumah di california
# * Metode : Linear Regression dan Random Forest Regressor
# * Video Demo : https://youtu.be/KDtiNnHm75Q

# %% [markdown]
# # Load libraries and dataset

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
housing = pd.read_csv(r'D:\Data F\Datasets\California Housing Data (1990)\housing.csv')

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# # Data exploration

# %% [markdown]
# Target variable : median house value

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
plt.figure(figsize=(12,8))
plt.scatter(housing['longitude'], housing['latitude'], alpha=0.5, cmap=plt.get_cmap('jet'), 
            c=housing['median_house_value'], s=housing['population']/100, label='population')
plt.colorbar()
plt.legend()
plt.show()

# %%
corr_matrix = housing.corr()
corr_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688075
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.049686
# population           -0.024650
# longitude            -0.045967
# latitude             -0.144160
# Name: median_house_value, dtype: float64

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Remove outliers
# hapus outliers dari fitur yang memiliki korelasi tertinggi
# * median income
# * total rooms
# * housing median age

# %%
sns.displot(housing['median_income'])

# %% [markdown]
# karena outliers di kanan, maka hapus 1% data atas atau ambil 99% persentil dari data

# %%
q = housing['median_income'].quantile(0.99)
housing_1 = housing[housing['median_income'] < q]

# %%
sns.displot(housing_1['median_income'])

# %%
sns.displot(housing['total_rooms'])

# %%
q = housing_1['total_rooms'].quantile(0.99)
housing_2 = housing_1[housing_1['total_rooms'] < q]

# %%
sns.displot(housing_2['total_rooms'])

# %%
sns.displot(housing['housing_median_age'])

# %%
q = housing_2['housing_median_age'].quantile(0.99)
housing_3 = housing_2[housing_2['housing_median_age'] < q]

# %%
sns.displot(housing_3['housing_median_age'])

# %%
housing_3.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  18987.000000  18987.000000        18987.000000  18987.000000
# mean    -119.488535     35.575814           27.282930   2539.881393
# std        1.974148      2.137538           11.322071   1673.846645
# min     -124.300000     32.540000            1.000000      2.000000
# 25%     -121.570000     33.920000           18.000000   1457.000000
# 50%     -118.450000     34.230000           28.000000   2136.000000
# 75%     -117.980000     37.650000           36.000000   3155.500000
# max     -114.310000     41.950000           51.000000  11181.000000
#
#        total_bedrooms    population    households  median_income  \
# count    18791.000000  18987.000000  18987.000000   18987.000000
# mean       523.121441   1398.774319    486.765260       3.777422
# std        344.868350    921.060018    315.437151       1.674638
# min          2.000000      3.000000      2.000000       0.499900
# 25%        299.000000    802.000000    282.000000       2.554700
# 50%        438.000000   1186.000000    412.000000       3.512900
# 75%        648.000000   1745.000000    606.000000       4.695700
# max       3638.000000  11272.000000   3405.000000      10.594100
#
#        median_house_value
# count        18987.000000
# mean        199346.180439
# std         109237.125319
# min          14999.000000
# 25%         117100.000000
# 50%         175000.000000
# 75%         253500.000000
# max         500001.000000

# %% [markdown]
# ## Data preparation for machine learning
# * numerik : menambal data null dengan median
# * kategori : one hot encoding
# * train test split (train : test => 70 : 30)

# %%
housing_labels = housing_3['median_house_value'].copy()
housing = housing_3.drop(['median_house_value'], axis=1)

# %%
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('std_scaler', StandardScaler())
])

# %%
num_attribs = list(housing.select_dtypes(include=np.number))
cat_attribs = ['ocean_proximity']

full_pipeline = ColumnTransformer([
    ('num', num_pipeline, num_attribs),
    ('cat', OneHotEncoder(), cat_attribs)
])

housing_prepared = full_pipeline.fit_transform(housing)

# %%
housing_prepared
# Out:
# array([[-1.38871877,  1.0779912 ,  1.21156547, ...,  0.        ,
#          1.        ,  0.        ],
#        [-1.38365316,  1.06863439, -0.55494226, ...,  0.        ,
#          1.        ,  0.        ],
#        [-1.40391559,  1.05927758,  1.29989085, ...,  0.        ,
#          1.        ,  0.        ],
#        ...,
#        [-0.87709228,  1.80314374, -0.9082438 , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.92774836,  1.80314374, -0.81991841, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.88722349,  1.77507332, -0.99656919, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
X_train, X_test, y_train, y_test = train_test_split(housing_prepared, housing_labels, test_size=0.3)

# %% [markdown]
# # Regression model

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ## Linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# nilai RMSE

# %%
predictions = lin_reg.predict(X_test)
# mse
np.sqrt(mean_squared_error(y_test, predictions))
# Out:
# 65317.09756517096

# %% [markdown]
# nilai Koefisien Determinasi (R squared)

# %%
lin_reg.score(X_test, y_test)
# Out:
# 0.6356886027473367

# %%
plt.scatter(y_test, predictions)

# %%
sns.displot(y_test - predictions)

# %% [markdown]
# ## Random forest regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
forest_reg = RandomForestRegressor()
forest_reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# Nilai Koefisien Determinasi (R Squared)

# %%
forest_reg.score(X_test, y_test)
# Out:
# 0.8121725294293048

# %% [markdown]
# Nilai RMSE

# %%
forest_predictions = forest_reg.predict(X_test)
np.sqrt(mean_squared_error(y_test, forest_predictions))
# Out:
# 47770.919558684924

# %%
plt.scatter(y_test, forest_predictions)

# %%
sns.displot(y_test - forest_predictions)

# %% [markdown]
# Menggunakan K-Fold Cross Validation

# %%
scores = cross_val_score(forest_reg, X_train, y_train, scoring='neg_mean_squared_error', cv=10)
forest_rmse_scores = np.sqrt(-scores)

# %%
forest_rmse_scores.mean()
# Out:
# 48931.61585959754

# %% [markdown]
# # Hyperparameters tuning for Random Forest Regressor

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = [
    {'n_estimators' : [120, 130, 140], 'max_features' : [6, 8], 'bootstrap' : [True, False]},
]

forest_reg2 = RandomForestRegressor()

grid_search_forest = GridSearchCV(
    forest_reg2, param_grid, cv=10, scoring='neg_mean_squared_error', return_train_score=True
)

# %%
grid_search_forest.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestRegressor(),
#              param_grid=[{'bootstrap': [True, False], 'max_features': [6, 8],
#                           'n_estimators': [120, 130, 140]}],
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search_forest.best_params_
# Out:
# {'bootstrap': False, 'max_features': 6, 'n_estimators': 130}

# %%
forest_cvres = grid_search_forest.cv_results_

for mean_score, params in zip(forest_cvres['mean_test_score'], forest_cvres['params']):
    print(np.sqrt(-mean_score), params)
# Out:
# 48636.67394496177 {'bootstrap': True, 'max_features': 6, 'n_estimators': 120}
# 48632.71142389475 {'bootstrap': True, 'max_features': 6, 'n_estimators': 130}
# 48572.27769739063 {'bootstrap': True, 'max_features': 6, 'n_estimators': 140}
# 48322.72467778623 {'bootstrap': True, 'max_features': 8, 'n_estimators': 120}
# 48458.85163044937 {'bootstrap': True, 'max_features': 8, 'n_estimators': 130}
# 48267.42088880144 {'bootstrap': True, 'max_features': 8, 'n_estimators': 140}
# 48178.595993346 {'bootstrap': False, 'max_features': 6, 'n_estimators': 120}
# 48004.88137318487 {'bootstrap': False, 'max_features': 6, 'n_estimators': 130}
# 48024.451115285636 {'bootstrap': False, 'max_features': 6, 'n_estimators': 140}
# 48281.22687487951 {'bootstrap': False, 'max_features': 8, 'n_estimators': 120}
# 48372.07980166493 {'bootstrap': False, 'max_features': 8, 'n_estimators': 130}
# 48344.65502276067 {'bootstrap': False, 'max_features': 8, 'n_estimators': 140}

# %% [markdown]
# ## Best model

# %%
forest_reg3 = RandomForestRegressor(max_features=6, n_estimators=130, bootstrap=False)
forest_reg3.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=False, max_features=6, n_estimators=130)

# %% [markdown]
# Nilai Koefisien Determinasi (R Squared)

# %%
forest_reg3.score(X_test, y_test)
# Out:
# 0.8179545154709831

# %% [markdown]
# Nilai RMSE

# %%
np.sqrt(mean_squared_error(y_test, forest_reg3.predict(X_test)))
# Out:
# 47029.89420713343

# %%
plt.scatter(y_test, forest_reg3.predict(X_test))
